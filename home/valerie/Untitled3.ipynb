# %%
"""
Script to find the newest 50 publications of an author on PubMed.
Requires: pip install biopython
"""

from Bio import Entrez
import time
import sys

def fetch_author_publications(author_name, email, max_results=50):
    """
    Fetch the newest publications for a given author from PubMed.
    
    Args:
        author_name (str): Author name (e.g., "Smith J" or "John Smith")
        email (str): Your email address (required by NCBI)
        max_results (int): Maximum number of results to return (default: 50)
    
    Returns:
        list: List of publication dictionaries with title, authors, journal, date, PMID
    """
    
    # Set email for NCBI (required)
    Entrez.email = email
    
    try:
        # Search for publications by author, sorted by publication date (newest first)
        search_query = f"{author_name}[Author]"
        
        print(f"Searching for publications by: {author_name}")
        print(f"Query: {search_query}")
        
        # Perform the search
        search_handle = Entrez.esearch(
            db="pubmed",
            term=search_query,
            retmax=max_results,
            sort="pub_date",  # Sort by publication date, newest first
            retmode="xml"
        )
        
        search_results = Entrez.read(search_handle)
        search_handle.close()
        
        pmid_list = search_results["IdList"]
        total_found = int(search_results["Count"])
        
        print(f"Found {total_found} total publications")
        print(f"Fetching details for newest {len(pmid_list)} publications...")
        
        if not pmid_list:
            print("No publications found for this author.")
            return []
        
        # Fetch detailed information for each publication
        publications = []
        batch_size = 10  # Process in batches to be nice to NCBI servers
        
        for i in range(0, len(pmid_list), batch_size):
            batch_pmids = pmid_list[i:i + batch_size]
            
            # Fetch publication details
            fetch_handle = Entrez.efetch(
                db="pubmed",
                id=",".join(batch_pmids),
                rettype="medline",
                retmode="xml"
            )
            
            records = Entrez.read(fetch_handle)
            fetch_handle.close()
            
            # Parse each record
            for record in records['PubmedArticle']:
                try:
                    article = record['MedlineCitation']['Article']
                    
                    # Extract publication info
                    title = article.get('ArticleTitle', 'No title available')
                    
                    # Get authors
                    authors = []
                    if 'AuthorList' in article:
                        for author in article['AuthorList']:
                            if 'LastName' in author and 'ForeName' in author:
                                authors.append(f"{author['LastName']} {author['ForeName']}")
                            elif 'CollectiveName' in author:
                                authors.append(author['CollectiveName'])
                    
                    # Get journal info
                    journal = article.get('Journal', {}).get('Title', 'Unknown journal')
                    
                    # Get publication date
                    pub_date = "Unknown date"
                    if 'Journal' in article and 'JournalIssue' in article['Journal']:
                        if 'PubDate' in article['Journal']['JournalIssue']:
                            date_info = article['Journal']['JournalIssue']['PubDate']
                            year = date_info.get('Year', '')
                            month = date_info.get('Month', '')
                            day = date_info.get('Day', '')
                            pub_date = f"{year} {month} {day}".strip()
                    
                    # Get PMID
                    pmid = record['MedlineCitation']['PMID']
                    
                    publications.append({
                        'title': title,
                        'authors': authors,
                        'journal': journal,
                        'date': pub_date,
                        'pmid': str(pmid),
                        'url': f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"
                    })
                    
                except KeyError as e:
                    print(f"Error parsing record: {e}")
                    continue
            
            # Be respectful to NCBI servers
            time.sleep(0.5)
        
        return publications
        
    except Exception as e:
        print(f"Error fetching publications: {e}")
        return []

def display_publications(publications):
    """Display publications in a formatted way."""
    
    if not publications:
        print("No publications to display.")
        return
    
    print(f"\n{'='*80}")
    print(f"FOUND {len(publications)} PUBLICATIONS")
    print(f"{'='*80}")
    
    for i, pub in enumerate(publications, 1):
        print(f"\n{i}. {pub['title']}")
        print(f"   Authors: {', '.join(pub['authors'][:3])}" + 
              (f" ... and {len(pub['authors'])-3} others" if len(pub['authors']) > 3 else ""))
        print(f"   Journal: {pub['journal']}")
        print(f"   Date: {pub['date']}")
        print(f"   PMID: {pub['pmid']}")
        print(f"   URL: {pub['url']}")

def save_to_file(publications, filename="publications.txt"):
    """Save publications to a text file."""
    
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(f"Found {len(publications)} publications\n")
        f.write("="*80 + "\n\n")
        
        for i, pub in enumerate(publications, 1):
            f.write(f"{i}. {pub['title']}\n")
            f.write(f"   Authors: {', '.join(pub['authors'])}\n")
            f.write(f"   Journal: {pub['journal']}\n")
            f.write(f"   Date: {pub['date']}\n")
            f.write(f"   PMID: {pub['pmid']}\n")
            f.write(f"   URL: {pub['url']}\n\n")
    
    print(f"Publications saved to {filename}")

def main():
    """Main function to run the script."""
    
    # Configuration - modify these values
    AUTHOR_NAME = "Vince I. Madai"  # Change this to the author you're searching for
    YOUR_EMAIL = "valbuerga@gmail.com"  # REQUIRED: Change to your email
    MAX_RESULTS = 50
    
    if YOUR_EMAIL == "your.email@example.com":
        print("ERROR: Please set your email address in the YOUR_EMAIL variable.")
        print("This is required by NCBI's terms of service.")
        sys.exit(1)
    
    # Fetch publications
    publications = fetch_author_publications(AUTHOR_NAME, YOUR_EMAIL, MAX_RESULTS)
    
    # Display results
    display_publications(publications)
    
    # Save to file
    if publications:
        save_to_file(publications, f"{AUTHOR_NAME.replace(' ', '_')}_publications.txt")

if __name__ == "__main__":
    main()
# Out:
# Searching for publications by: Vince I. Madai
# Query: Vince I. Madai[Author]
# Found 64 total publications
# Fetching details for newest 50 publications...
#
# ================================================================================
# FOUND 50 PUBLICATIONS
# ================================================================================
#
# 1. Early Complications After Mild to Moderate Ischemic Stroke and Impact on 3-Month Outcome: The Multicenter Prospective Stroke Unit Plus Cohort Study.
#    Authors: Sobesky Jan, Madai Vince Istvan, Zweynert Sarah ... and 14 others
#    Journal: Journal of the American Heart Association
#    Date: 2025 Feb 18
#    PMID: 39921500
#    URL: https://pubmed.ncbi.nlm.nih.gov/39921500/
#
# 2. External validation of AI-based scoring systems in the ICU: a systematic review and meta-analysis.
#    Authors: Rockenschaub Patrick, Akay Ela Marie, Carlisle Benjamin Gregory ... and 6 others
#    Journal: BMC medical informatics and decision making
#    Date: 2025 Jan 06
#    PMID: 39762808
#    URL: https://pubmed.ncbi.nlm.nih.gov/39762808/
#
# 3. The authors reply.
#    Authors: Rockenschaub Patrick, Madai Vince Istvan, Frey Dietmar
#    Journal: Critical care medicine
#    Date: 2024 Dec 01
#    PMID: 39637279
#    URL: https://pubmed.ncbi.nlm.nih.gov/39637279/
#
# 4. The Impact of Multi-Institution Datasets on the Generalizability of Machine Learning Prediction Models in the ICU.
#    Authors: Rockenschaub Patrick, Hilbert Adam, Kossen Tabea ... and 4 others
#    Journal: Critical care medicine
#    Date: 2024 Nov 01
#    PMID: 38958568
#    URL: https://pubmed.ncbi.nlm.nih.gov/38958568/
#
# 5. Perfusion parameter map generation from TOF-MRA in stroke using generative adversarial networks.
#    Authors: Lohrke Felix, Madai Vince Istvan, Kossen Tabea ... and 7 others
#    Journal: NeuroImage
#    Date: 2024 Sep
#    PMID: 39117094
#    URL: https://pubmed.ncbi.nlm.nih.gov/39117094/
#
# 6. Automated detection of early signs of irreversible ischemic change on CTA source images in patients with large vessel occlusion.
#    Authors: Mak Adrian, Matouk Charles C, Avery Emily W ... and 16 others
#    Journal: PloS one
#    Date: 2024
#    PMID: 38870240
#    URL: https://pubmed.ncbi.nlm.nih.gov/38870240/
#
# 7. The unmet promise of trustworthy AI in healthcare: why we fail at clinical translation.
#    Authors: Bürger Valerie K, Amann Julia, Bui Cathrine K T ... and 2 others
#    Journal: Frontiers in digital health
#    Date: 2024
#    PMID: 38698888
#    URL: https://pubmed.ncbi.nlm.nih.gov/38698888/
#
# 8. A trustworthy AI reality-check: the lack of transparency of artificial intelligence products in healthcare.
#    Authors: Fehr Jana, Citro Brian, Malpani Rohit ... and 2 others
#    Journal: Frontiers in digital health
#    Date: 2024
#    PMID: 38455991
#    URL: https://pubmed.ncbi.nlm.nih.gov/38455991/
#
# 9. Long-term trajectories of community integration: identification, characterization, and prediction using inpatient rehabilitation variables.
#    Authors: Garcia-Rudolph Alejandro, Sauri Joan, Cisek Katryna ... and 6 others
#    Journal: Topics in stroke rehabilitation
#    Date: 2023 Oct
#    PMID: 36934334
#    URL: https://pubmed.ncbi.nlm.nih.gov/36934334/
#
# 10. Personalised simulation of hemodynamics in cerebrovascular disease: lessons learned from a study of diagnostic accuracy.
#    Authors: Behland Jonas, Madai Vince I, Aydin Orhun U ... and 6 others
#    Journal: Frontiers in neurology
#    Date: 2023
#    PMID: 37771452
#    URL: https://pubmed.ncbi.nlm.nih.gov/37771452/
#
# 11. Enhancing the prediction for shunt-dependent hydrocephalus after aneurysmal subarachnoid hemorrhage using a machine learning approach.
#    Authors: Frey Dietmar, Hilbert Adam, Früh Anton ... and 10 others
#    Journal: Neurosurgical review
#    Date: 2023 Aug 19
#    PMID: 37596512
#    URL: https://pubmed.ncbi.nlm.nih.gov/37596512/
#
# 12. Artificial Intelligence for Clinical Decision Support in Acute Ischemic Stroke: A Systematic Review.
#    Authors: Akay Ela Marie Z, Hilbert Adam, Carlisle Benjamin G ... and 3 others
#    Journal: Stroke
#    Date: 2023 Jun
#    PMID: 37216446
#    URL: https://pubmed.ncbi.nlm.nih.gov/37216446/
#
# 13. Machine Learning-Based Identification of Target Groups for Thrombectomy in Acute Stroke.
#    Authors: Quandt Fanny, Flottmann Fabian, Madai Vince I ... and 13 others
#    Journal: Translational stroke research
#    Date: 2023 Jun
#    PMID: 35670996
#    URL: https://pubmed.ncbi.nlm.nih.gov/35670996/
#
# 14. Expectations and attitudes towards medical artificial intelligence: A qualitative study in the field of stroke.
#    Authors: Amann Julia, Vayena Effy, Ormond Kelly E ... and 3 others
#    Journal: PloS one
#    Date: 2023
#    PMID: 36630325
#    URL: https://pubmed.ncbi.nlm.nih.gov/36630325/
#
# 15. Image-to-image generative adversarial networks for synthesizing perfusion parameter maps from DSC-MR images in cerebrovascular disease.
#    Authors: Kossen Tabea, Madai Vince I, Mutke Matthias A ... and 8 others
#    Journal: Frontiers in neurology
#    Date: 2022
#    PMID: 36703627
#    URL: https://pubmed.ncbi.nlm.nih.gov/36703627/
#
# 16. A deep learning analysis of stroke onset time prediction and comparison to DWI-FLAIR mismatch.
#    Authors: Akay Ela Marie Z, Rieger Jana, Schöttler Ricardo ... and 9 others
#    Journal: NeuroImage. Clinical
#    Date: 2023
#    PMID: 38000188
#    URL: https://pubmed.ncbi.nlm.nih.gov/38000188/
#
# 17. Predicting models for arm impairment: External validation of the Scandinavian models and identification of new predictors in post-acute stroke settings.
#    Authors: García-Rudolph Alejandro, Soriano Ignasi, Becerra Helard ... and 5 others
#    Journal: NeuroRehabilitation
#    Date: 2023
#    PMID: 37248917
#    URL: https://pubmed.ncbi.nlm.nih.gov/37248917/
#
# 18. Generating evidence on privacy outcomes to inform privacy risk management: A way forward?
#    Authors: Strech Daniel, Haven Tamarinde, Madai Vince I ... and 2 others
#    Journal: Journal of biomedical informatics
#    Date: 2023 Jan
#    PMID: 36462598
#    URL: https://pubmed.ncbi.nlm.nih.gov/36462598/
#
# 19. Assessing Trustworthy AI in Times of COVID-19: Deep Learning for Predicting a Multiregional Score Conveying the Degree of Lung Compromise in COVID-19 Patients.
#    Authors: Allahabadi Himanshi, Amann Julia, Balot Isabelle ... and 54 others
#    Journal: IEEE transactions on technology and society
#    Date: 2022 Dec
#    PMID: 36573115
#    URL: https://pubmed.ncbi.nlm.nih.gov/36573115/
#
# 20. Correction: On the usage of average Hausdorff distance for segmentation performance assessment: hidden error when used for ranking.
#    Authors: Aydin Orhun Utku, Taha Abdel Aziz, Hilbert Adam ... and 5 others
#    Journal: European radiology experimental
#    Date: 2022 Oct 31
#    PMID: 36315317
#    URL: https://pubmed.ncbi.nlm.nih.gov/36315317/
#
# 21. Anatomical labeling of intracranial arteries with deep learning in patients with cerebrovascular disease.
#    Authors: Hilbert Adam, Rieger Jana, Madai Vince I ... and 9 others
#    Journal: Frontiers in neurology
#    Date: 2022
#    PMID: 36341105
#    URL: https://pubmed.ncbi.nlm.nih.gov/36341105/
#
# 22. Similar admission NIHSS may represent larger tissue-at-risk in patients with right-sided versus left-sided large vessel occlusion.
#    Authors: Mak Adrian, Matouk Charles, Avery Emily W ... and 12 others
#    Journal: Journal of neurointerventional surgery
#    Date: 2022 Oct
#    PMID: 34645705
#    URL: https://pubmed.ncbi.nlm.nih.gov/34645705/
#
# 23. You Can't Have AI Both Ways: Balancing Health Data Privacy and Access Fairly.
#    Authors: Bak Marieke, Madai Vince Istvan, Fritzsche Marie-Christine ... and 2 others
#    Journal: Frontiers in genetics
#    Date: 2022
#    PMID: 35769991
#    URL: https://pubmed.ncbi.nlm.nih.gov/35769991/
#
# 24. Comparing Poor and Favorable Outcome Prediction With Machine Learning After Mechanical Thrombectomy in Acute Ischemic Stroke.
#    Authors: Mutke Matthias A, Madai Vince I, Hilbert Adam ... and 9 others
#    Journal: Frontiers in neurology
#    Date: 2022
#    PMID: 35693017
#    URL: https://pubmed.ncbi.nlm.nih.gov/35693017/
#
# 25. Toward Sharing Brain Images: Differentially Private TOF-MRA Images With Segmentation Labels Using Generative Adversarial Networks.
#    Authors: Kossen Tabea, Hirzel Manuel A, Madai Vince I ... and 11 others
#    Journal: Frontiers in artificial intelligence
#    Date: 2022
#    PMID: 35586223
#    URL: https://pubmed.ncbi.nlm.nih.gov/35586223/
#
# 26. Generating 3D TOF-MRA volumes and segmentation labels using generative adversarial networks.
#    Authors: Subramaniam Pooja, Kossen Tabea, Ritter Kerstin ... and 10 others
#    Journal: Medical image analysis
#    Date: 2022 May
#    PMID: 35231850
#    URL: https://pubmed.ncbi.nlm.nih.gov/35231850/
#
# 27. The impact of COVID-19 on home, social, and productivity integration of people with chronic traumatic brain injury or stroke living in the community.
#    Authors: García-Rudolph Alejandro, Saurí Joan, Cegarra Blanca ... and 5 others
#    Journal: Medicine
#    Date: 2022 Feb 25
#    PMID: 35212272
#    URL: https://pubmed.ncbi.nlm.nih.gov/35212272/
#
# 28. To explain or not to explain?-Artificial intelligence explainability in clinical decision support systems.
#    Authors: Amann Julia, Vetter Dennis, Blomberg Stig Nikolaj ... and 12 others
#    Journal: PLOS digital health
#    Date: 2022 Feb
#    PMID: 36812545
#    URL: https://pubmed.ncbi.nlm.nih.gov/36812545/
#
# 29. Long-term trajectories of motor functional independence after ischemic stroke in young adults: Identification and characterization using inpatient baseline assessments.
#    Authors: García-Rudolph Alejandro, Saurí Joan, Cegarra Blanca ... and 7 others
#    Journal: NeuroRehabilitation
#    Date: 2022
#    PMID: 35147566
#    URL: https://pubmed.ncbi.nlm.nih.gov/35147566/
#
# 30. The impact of coronavirus disease 2019 on emotional and behavioral stress of informal family caregivers of individuals with stroke or traumatic brain injury at chronic phase living in a Mediterranean setting.
#    Authors: Garcia-Rudolph Alejandro, Sauri Joan, Garcia-Molina Alberto ... and 6 others
#    Journal: Brain and behavior
#    Date: 2022 Jan
#    PMID: 34910375
#    URL: https://pubmed.ncbi.nlm.nih.gov/34910375/
#
# 31. Toward Personalized Web-Based Cognitive Rehabilitation for Patients With Ischemic Stroke: Elo Rating Approach.
#    Authors: Garcia-Rudolph Alejandro, Opisso Eloy, Tormos Jose M ... and 6 others
#    Journal: JMIR medical informatics
#    Date: 2021 Nov 10
#    PMID: 34757325
#    URL: https://pubmed.ncbi.nlm.nih.gov/34757325/
#
# 32. Outcome prediction in aneurysmal subarachnoid hemorrhage: a comparison of machine learning methods and established clinico-radiological scores.
#    Authors: Dengler Nora Franziska, Madai Vince Istvan, Unteroberdörster Meike ... and 7 others
#    Journal: Neurosurgical review
#    Date: 2021 Oct
#    PMID: 33474607
#    URL: https://pubmed.ncbi.nlm.nih.gov/33474607/
#
# 33. Neuropsychological Assessments of Patients With Acquired Brain Injury: A Cluster Analysis Approach to Address Heterogeneity in Web-Based Cognitive Rehabilitation.
#    Authors: García-Rudolph Alejandro, García-Molina Alberto, Opisso Eloy ... and 4 others
#    Journal: Frontiers in neurology
#    Date: 2021
#    PMID: 34434163
#    URL: https://pubmed.ncbi.nlm.nih.gov/34434163/
#
# 34. An evaluation of performance measures for arterial brain vessel segmentation.
#    Authors: Aydin Orhun Utku, Taha Abdel Aziz, Hilbert Adam ... and 5 others
#    Journal: BMC medical imaging
#    Date: 2021 Jul 16
#    PMID: 34271876
#    URL: https://pubmed.ncbi.nlm.nih.gov/34271876/
#
# 35. A precision medicine framework for personalized simulation of hemodynamics in cerebrovascular disease.
#    Authors: Frey Dietmar, Livne Michelle, Leppin Heiko ... and 6 others
#    Journal: Biomedical engineering online
#    Date: 2021 May 01
#    PMID: 33933080
#    URL: https://pubmed.ncbi.nlm.nih.gov/33933080/
#
# 36. Synthesizing anonymized and labeled TOF-MRA patches for brain vessel segmentation using generative adversarial networks.
#    Authors: Kossen Tabea, Subramaniam Pooja, Madai Vince I ... and 9 others
#    Journal: Computers in biology and medicine
#    Date: 2021 Apr
#    PMID: 33618105
#    URL: https://pubmed.ncbi.nlm.nih.gov/33618105/
#
# 37. On the usage of average Hausdorff distance for segmentation performance assessment: hidden error when used for ranking.
#    Authors: Aydin Orhun Utku, Taha Abdel Aziz, Hilbert Adam ... and 5 others
#    Journal: European radiology experimental
#    Date: 2021 Jan 21
#    PMID: 33474675
#    URL: https://pubmed.ncbi.nlm.nih.gov/33474675/
#
# 38. Predictive models for independence after stroke rehabilitation: Maugeri external validation and development of a new model.
#    Authors: García-Rudolph Alejandro, Bernabeu Montserrat, Cegarra Blanca ... and 5 others
#    Journal: NeuroRehabilitation
#    Date: 2021
#    PMID: 34542037
#    URL: https://pubmed.ncbi.nlm.nih.gov/34542037/
#
# 39. Hybrid modelling for stroke care: Review and suggestions of new approaches for risk assessment and simulation of scenarios.
#    Authors: Herrgårdh Tilda, Madai Vince I, Kelleher John D ... and 5 others
#    Journal: NeuroImage. Clinical
#    Date: 2021
#    PMID: 34000646
#    URL: https://pubmed.ncbi.nlm.nih.gov/34000646/
#
# 40. Explainability for artificial intelligence in healthcare: a multidisciplinary perspective.
#    Authors: Amann Julia, Blasimme Alessandro, Vayena Effy ... and 3 others
#    Journal: BMC medical informatics and decision making
#    Date: 2020 Nov 30
#    PMID: 33256715
#    URL: https://pubmed.ncbi.nlm.nih.gov/33256715/
#
# 41. BRAVE-NET: Fully Automated Arterial Brain Vessel Segmentation in Patients With Cerebrovascular Disease.
#    Authors: Hilbert Adam, Madai Vince I, Akay Ela M ... and 12 others
#    Journal: Frontiers in artificial intelligence
#    Date: 2020
#    PMID: 33733207
#    URL: https://pubmed.ncbi.nlm.nih.gov/33733207/
#
# 42. Opening the black box of artificial intelligence for clinical decision support: A study predicting stroke outcome.
#    Authors: Zihni Esra, Madai Vince Istvan, Livne Michelle ... and 4 others
#    Journal: PloS one
#    Date: 2020
#    PMID: 32251471
#    URL: https://pubmed.ncbi.nlm.nih.gov/32251471/
#
# 43. Brain iron and metabolic abnormalities in C19orf12 mutation carriers: A 7.0 tesla MRI study in mitochondrial membrane protein-associated neurodegeneration.
#    Authors: Dusek Petr, Mekle Ralf, Skowronska Marta ... and 15 others
#    Journal: Movement disorders : official journal of the Movement Disorder Society
#    Date: 2020 Jan
#    PMID: 31518459
#    URL: https://pubmed.ncbi.nlm.nih.gov/31518459/
#
# 44. Diagnostic and prognostic benefit of arterial spin labeling in subacute stroke.
#    Authors: Thamm Thoralf, Zweynert Sarah, Piper Sophie K ... and 8 others
#    Journal: Brain and behavior
#    Date: 2019 May
#    PMID: 30912272
#    URL: https://pubmed.ncbi.nlm.nih.gov/30912272/
#
# 45. The choice of embedding media affects image quality, tissue R<sub>2</sub><sup>*</sup> , and susceptibility behaviors in post-mortem brain MR microscopy at 7.0T.
#    Authors: Dusek Petr, Madai Vince Istvan, Huelnhagen Till ... and 6 others
#    Journal: Magnetic resonance in medicine
#    Date: 2019 Apr
#    PMID: 30506939
#    URL: https://pubmed.ncbi.nlm.nih.gov/30506939/
#
# 46. A U-Net Deep Learning Framework for High Performance Vessel Segmentation in Patients With Cerebrovascular Disease.
#    Authors: Livne Michelle, Rieger Jana, Aydin Orhun Utku ... and 8 others
#    Journal: Frontiers in neuroscience
#    Date: 2019
#    PMID: 30872986
#    URL: https://pubmed.ncbi.nlm.nih.gov/30872986/
#
# 47. A PET-Guided Framework Supports a Multiple Arterial Input Functions Approach in DSC-MRI in Acute Stroke.
#    Authors: Livne Michelle, Madai Vince I, Brunecker Peter ... and 5 others
#    Journal: Journal of neuroimaging : official journal of the American Society of Neuroimaging
#    Date: 2017 Sep
#    PMID: 28207200
#    URL: https://pubmed.ncbi.nlm.nih.gov/28207200/
#
# 48. Multiparametric Model for Penumbral Flow Prediction in Acute Stroke.
#    Authors: Livne Michelle, Kossen Tabea, Madai Vince I ... and 5 others
#    Journal: Stroke
#    Date: 2017 Jul
#    PMID: 28630234
#    URL: https://pubmed.ncbi.nlm.nih.gov/28630234/
#
# 49. Walsh-ordered hadamard time-encoded pseudocontinuous ASL (WH pCASL).
#    Authors: von Samson-Himmelstjerna Federico, Madai Vince Istvan, Sobesky Jan ... and 1 others
#    Journal: Magnetic resonance in medicine
#    Date: 2016 Dec
#    PMID: 26714671
#    URL: https://pubmed.ncbi.nlm.nih.gov/26714671/
#
# 50. Correction for Susceptibility Distortions Increases the Performance of Arterial Spin Labeling in Patients with Cerebrovascular Disease.
#    Authors: Madai Vince I, Martin Steve Z, von Samson-Himmelstjerna Federico C ... and 9 others
#    Journal: Journal of neuroimaging : official journal of the American Society of Neuroimaging
#    Date: 2016 Jul
#    PMID: 26902457
#    URL: https://pubmed.ncbi.nlm.nih.gov/26902457/
# Publications saved to Vince_I._Madai_publications.txt
